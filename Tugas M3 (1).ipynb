# %%
# soal no 1

Nama=input("Masukan Nama pelanggan:")
alamat=input("masukan alamat:")
Usia=int(input("masukan usia:"))
print("Nama :", Nama)
print("Alamat :", alamat)
print("Usia :", Usia)
# Out:
# Masukan Nama pelanggan: Aliyah
# masukan alamat: Kota Padang
# masukan usia: 18
# Nama : Aliyah
# Alamat : Kota Padang
# Usia : 18

# %%
# Soal ke 2

Modal_awal=float(input("masukan modal awal:"))
Target_keuntungan=Modal_awal*0.20
Total=Modal_awal+Target_keuntungan 

print("Modal Awal :", Modal_awal)
print("Target keuntungan :", Target_keuntungan)
print("Total :", Total)
# Out:
# masukan modal awal: 1000000
# Modal Awal : 1000000.0
# Target keuntungan : 200000.0
# Total : 1200000.0

# %%
# Soal no 3

hari=input("masukan hari:")
bulan=input("masukan bulan:")
tahun=input("masukan tahun:")
print(hari,bulan,tahun, sep="-")

# %%
# soal no.4
print(f"{"ID":<5}{"Produk":<10}{"Harga":<10}")
print("-" * 25)
# Out:
# ID   Produk    Harga
# -------------------------

# %%
# soal no.5
Barang="Kalkulator Saintifik"
Harga= 245000.5

print(f"Harga {Barang} adalah Rp{Harga:,.2f}")
# Out:
# Harga Kalkulator Saintifik adalah Rp245,000.50

# %%
# soal no.6

#input data
Nama=input("Nama lengkap :")
Usia=int(input("usia :"))
Kontak=input("No. kontak :")
Alamat=input("alamat asal :")
Kampus=input("kampus :")
Fakultas=input("Fakultas :")
Departemen=input("Departemen :")
NRP=input("nrp :")
Angkatan=int(input("Angkatan :"))
SKS=int(input("Jumlah sks :"))
Matkul=input("Mata kuliah : ")
Karier=input("Target karier :")

#tampilan
Usia_Kontak =f"{Usia} Tahun | {Kontak}"
fakultas_dept=f"{Fakultas} / {Departemen}"
nrp_angkatan= f"{NRP} / {Angkatan}"
sks_matkul=f"{SKS} SKS | {Matkul}"
Lebar= 70
garisdouble= "=" * Lebar
garistunggal="-" * Lebar



#output
print(garisdouble)
print(f"| {"DASBOR PROFIL MAHASISWA & RENCANA KARIER":^67}|")
print(garisdouble)

print(f"| {"INFORMASI PERSONAL":<67}|")
print(garistunggal)
print(f"| {"Nama Lengkap":<16}: {Nama:<49}|")
print(f"| {"Usia & Kontak":<16}: {Usia_Kontak:<49}|")
print(f"| {"Alamat Asal":<16}: {Alamat:<49}|")
print(garistunggal)

print(f"| {"INFORMASI AKADEMIK":<67}|")
print(garistunggal)
print(f"| {"Kampus":<16}: {Kampus:<49}|")
print(f"| {"Fakultas / Dept":<16}: {fakultas_dept:<49}|")
print(f"| {"NRP / Angkatan":<16}: {nrp_angkatan:<49}|")
print(f"| {"SKS & Matkul":<16}: {sks_matkul:<49}|")
print(garisdouble)

print(f"| {"TARGET KARIER (DREAM JOB)":^67}|")
print(f"| {Karier.upper():^67}|")
print(garisdouble)
# Out:
# Nama lengkap : Aliyah Nabilatus Salamah
# usia : 18
# No. kontak : 081266257121
# alamat asal : Kota Padang
# kampus : Institut Teknologi Sepuluh Nopember
# Fakultas : Vokasi
# Departemen : Statistika Bisnis
# nrp : 2043261027
# Angkatan : 2026
# Jumlah sks : 36
# Mata kuliah :  Algoritma Pemrograman
# Target karier : orang sukses
# ...
# |              DASBOR PROFIL MAHASISWA & RENCANA KARIER              |
# ...
# | INFORMASI PERSONAL                                                 |
# ----------------------------------------------------------------------
# | Nama Lengkap    : Aliyah Nabilatus Salamah                         |
# | Usia & Kontak   : 18 Tahun | 081266257121                          |
# | Alamat Asal     : Kota Padang                                      |
# ----------------------------------------------------------------------
# | INFORMASI AKADEMIK                                                 |
# ----------------------------------------------------------------------
# ...
